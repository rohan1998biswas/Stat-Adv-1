# %%
# Statistics Advance 1

# %%
'''8. You have two sets of data representing the incomes of two different professions
 Profession A: [48, 52, 55, 60, 62
 Profession B: [45, 50, 55, 52, 47] Perform an F-test to determine if the variances of the two professions'
incomes are equal. What are your conclusions based on the F-test?
 Task: Use Python to calculate the F-statistic and p-value for the given data.
 Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison.'''
# Out:
# "8. You have two sets of data representing the incomes of two different professions\n Profession A: [48, 52, 55, 60, 62\n Profession B: [45, 50, 55, 52, 47] Perform an F-test to determine if the variances of the two professions'\nincomes are equal. What are your conclusions based on the F-test?\n Task: Use Python to calculate the F-statistic and p-value for the given data.\n Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison."

# %%
import numpy as np
from scipy import stats

prof_A = np.array([48, 52, 55, 60, 62])
prof_B = np.array([45, 50, 55, 52, 47])
var_A = np.var(prof_A, ddof=1)
var_B = np.var(prof_B, ddof=1)

F_statistic = var_A / var_B
df1 = len(prof_A) - 1
df2 = len(prof_B) - 1

p_value = 1 - stats.f.cdf(F_statistic, df1, df2)

print("F-statistic:", F_statistic)
print("p-value:", p_value)
# Out:
# F-statistic: 2.089171974522293
# p-value: 0.24652429950266952

# %%
''' 9. Conduct a one-way ANOVA to test whether there are any statistically significant differences in
average heights between three different regions with the following data
 Region A: [160, 162, 165, 158, 164
 Region B: [172, 175, 170, 168, 174
 Region C: [180, 182, 179, 185, 183
 Task: Write Python code to perform the one-way ANOVA and interpret the results
 Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value.'''
# Out:
# ' 9. Conduct a one-way ANOVA to test whether there are any statistically significant differences in\naverage heights between three different regions with the following data\n Region A: [160, 162, 165, 158, 164\n Region B: [172, 175, 170, 168, 174\n Region C: [180, 182, 179, 185, 183\n Task: Write Python code to perform the one-way ANOVA and interpret the results\n Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value.'

# %%
# Ans:
region_A = [160, 162, 165, 158, 164]
region_B = [172, 175, 170, 168, 174]
region_C = [180, 182, 179, 185, 183]

f_statistic, p_value = stats.f_oneway(region_A, region_B, region_C)

print("F-statistic:", f_statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is significant difference between the means of three regions.")
else:
    print("There is no significant difference between the means of three regions.")
# Out:
# F-statistic: 67.87330316742101
# p-value: 2.870664187937026e-07
# There is significant difference between the means of three regions.
